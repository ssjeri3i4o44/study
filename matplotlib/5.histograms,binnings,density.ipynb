# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = np.random.randn(1000)

# %%
plt.hist(data);

# %%
plt.hist(data, bins = 30, density = True, alpha = 0.8,
        histtype = 'stepfilled', color = 'steelblue', edgecolor = 'none');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2,1,1000)
x3 = np.random.normal(3,2,1000)

kwargs = dict(histtype = 'stepfilled', alpha = 0.3, density = True, bins = 40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.00678803, 0.        , 0.02036408, 0.00678803, 0.01697007,
#         0.02715211, 0.03733415, 0.05769823, 0.06109224, 0.08145632,
#         0.06448626, 0.10860843, 0.11539646, 0.13236653, 0.16291265,
#         0.11879047, 0.24436897, 0.1764887 , 0.21042884, 0.15273061,
#         0.22739891, 0.22061088, 0.16291265, 0.15612462, 0.1493366 ,
#         0.12897251, 0.11879047, 0.13576054, 0.07806231, 0.0509102 ,
#         0.03394014, 0.03394014, 0.02036408, 0.00678803, 0.02715211,
#         0.01357605, 0.01357605, 0.00339401, 0.00339401, 0.00678803]),
#  array([-2.61927726, -2.32464084, -2.03000442, -1.735368  , -1.44073157,
#         -1.14609515, -0.85145873, -0.55682231, -0.26218589,  0.03245053,
#          0.32708696,  0.62172338,  0.9163598 ,  1.21099622,  1.50563264,
#          1.80026906,  2.09490549,  2.38954191,  2.68417833,  2.97881475,
#          3.27345117,  3.56808759,  3.86272402,  4.15736044,  4.45199686,
#          4.74663328,  5.0412697 ,  5.33590612,  5.63054255,  5.92517897,
#          6.21981539,  6.51445181,  6.80908823,  7.10372465,  7.39836108,
#          7.6929975 ,  7.98763392,  8.28227034,  8.57690676,  8.87154319,
#          9.16617961]),
#  <a list of 1 Patch objects>)

# %%
#计算图中bin个数
counts, bin_edges = np.histogram(data, bins = 5)
print(counts)
print(bin_edges)
# Out:
# [ 54 349 423 158  16]
# [-2.75379686 -1.53402985 -0.31426283  0.90550418  2.1252712   3.34503821]

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins = 30, cmap = 'Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %%
plt.hexbin(x, y, gridsize = 30, cmap = 'Blues')
cb = plt.colorbar(label = 'count in bin')
